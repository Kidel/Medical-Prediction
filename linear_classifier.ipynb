# %%
# %matplotlib inline
import tensorflow as tf

import numpy as np
# Explicit random seed for reproducibility
np.random.seed(7)  
import os
import matplotlib.pyplot as plt

tf.__version__
# Out:
# '1.4.0'

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
def normalize(data, coefficients):
    data = np.array(data, dtype=np.float32)
    for index, c in enumerate(coefficients): 
        data[:,index] /= c
    return data

# %%
def load_training_data(filename="data.csv", delimiter=";", skiprows=1, class1='NORMAL', class2='TRISOMY 21', force=False, normalization=True, 
                      column_mask=[False, False, False, False, False, True, True, True, True, True, False, True, True, True]):
    filepath = os.path.join('data', filename)
    npy_filepath_x = os.path.join('data', filename + '_x.npy')
    npy_filepath_y = os.path.join('data', filename + '_y.npy')
    npy_filepath_coefficients = os.path.join('data', filename + '_coefficients.npy')
    npy_filepath_ids = os.path.join('data', filename + '_id.npy')
    x = []
    y = []
    coefficients = [1]*8
    ids = []
    if force or not os.path.isfile(npy_filepath_x) or not os.path.isfile(npy_filepath_y) \
    or not os.path.isfile(npy_filepath_coefficients) or not os.path.isfile(npy_filepath_ids):
        raw_data = np.loadtxt(filepath, delimiter=delimiter, skiprows=skiprows, dtype=str)
        for line in raw_data:
            app = [n for n in line]
            app = np.array(app)
            m = np.array(column_mask)
            app = [float(n) for n in app[m]]
            x.append(np.asarray(app))
            y.append(0 if line[1] == class1 else 1)
            ids.append(line[0])
        x = np.array(x)
        y = np.array(y)
        ids = np.array(ids)
        if normalization:
            coefficients = x.max(axis=0)
            x = x / x.max(axis=0)
        np.save(npy_filepath_x, x)
        np.save(npy_filepath_y, y)
        np.save(npy_filepath_coefficients, coefficients)
        np.save(npy_filepath_ids, ids)
    else:
        x = np.load(npy_filepath_x)
        y = np.load(npy_filepath_y)
        coefficients = np.load(npy_filepath_coefficients)
        ids = np.load(npy_filepath_ids)

    return coefficients, x, y, ids

# %%
def load_blind_data(coefficients, filename="blind_samples.csv", delimiter=";", skiprows=1, force=False, normalization=True, 
                      column_mask=[False, True, True, True, True, True, True, True, True]):
    filepath = os.path.join('data', filename)
    npy_filepath_x = os.path.join('data', filename + '_x.npy')
    npy_filepath_ids = os.path.join('data', filename + '_id.npy')
    x = []
    ids = []
    if force or not os.path.isfile(npy_filepath_x) or not os.path.isfile(npy_filepath_ids):
        raw_data = np.loadtxt(filepath, delimiter=delimiter, skiprows=skiprows, dtype=str)
        for line in raw_data:
            app = [n for n in line]
            app = np.array(app)
            m = np.array(column_mask)
            app = [float(n) for n in app[m]]
            x.append(np.asarray(app))
            ids.append(line[0])
        x = np.array(x)
        ids = np.array(ids)
        if normalization:
            x = normalize(x, coefficients)
        np.save(npy_filepath_x, x)
        np.save(npy_filepath_ids, ids)
    else:
        x = np.load(npy_filepath_x)
        ids = np.load(npy_filepath_ids)
    return x, ids

# %%
(coefficients, x, y, ids) = load_training_data(force=True);

# %%
batch_size = 512
nb_classes = 2
nb_epoch = 150
# dense layer size
dense_layer_size1 = 100
# checkpoint path
checkpoints_filepath = "checkpoints/checkpoints.hdf5"
class_names = ['NORMAL', 'TRISOMY 21']

training_set_size_percentage = 100 # set to 70 or 80 during tuning

# %%
if training_set_size_percentage == 100:
    X_train = x
    X_test = x
    Y_train = y
    Y_test = y
else: 
    size = y.size
    training_size = int((size/100)*training_set_size_percentage)

    X_train = x[0:training_size]
    X_test = x[training_size:size]

    Y_train = y[0:training_size]
    Y_test = y[training_size:size]
    
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1])

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(Y_train, nb_classes)
Y_test = np_utils.to_categorical(Y_test, nb_classes)
# Out:
# X_train shape: (40, 8)
# 40 train samples
# 40 test samples

# %%
def initialize_network_single_column(model, nb_classes, dense_layer_size1):
    model.add(Dense(dense_layer_size1, name='fully_connected_1_' + str(dense_layer_size1) + '_neurons', 
                    input_shape=(8, )))
    model.add(Activation('relu', name='activation_1_' + 'relu'))
    model.add(Dropout(0.25))
    model.add(Dense(nb_classes, name='output_' + str(nb_classes) + '_neurons'))
    model.add(Activation('softmax', name='softmax'))
    model.compile(loss='categorical_crossentropy',
                  optimizer='adadelta',
                  metrics=['acc'])
        
model = Sequential()
initialize_network_single_column(model, nb_classes, dense_layer_size1)

# %%
# fits the model on clear training set, for nb_epoch-700 epochs
history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch,
                    verbose=1, validation_data=(X_test, Y_test))
# Out:
# Train on 40 samples, validate on 40 samples
# Epoch 1/150
# 40/40 [==============================] - 1s 26ms/step - loss: 0.7142 - acc: 0.6000 - val_loss: 0.7154 - val_acc: 0.5750
# Epoch 2/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.7213 - acc: 0.5750 - val_loss: 0.7129 - val_acc: 0.5500
# Epoch 3/150
# 40/40 [==============================] - 0s 213us/step - loss: 0.7206 - acc: 0.4750 - val_loss: 0.7104 - val_acc: 0.5250
# Epoch 4/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6970 - acc: 0.6000 - val_loss: 0.7081 - val_acc: 0.5250
# Epoch 5/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.7188 - acc: 0.5000 - val_loss: 0.7057 - val_acc: 0.5250
# Epoch 6/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.7074 - acc: 0.4750 - val_loss: 0.7034 - val_acc: 0.5000
# Epoch 7/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.7024 - acc: 0.7000 - val_loss: 0.7011 - val_acc: 0.5000
# Epoch 8/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6953 - acc: 0.5000 - val_loss: 0.6991 - val_acc: 0.5250
# Epoch 9/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.7080 - acc: 0.5000 - val_loss: 0.6970 - val_acc: 0.5000
# Epoch 10/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.6778 - acc: 0.5500 - val_loss: 0.6951 - val_acc: 0.5000
# Epoch 11/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6783 - acc: 0.6500 - val_loss: 0.6932 - val_acc: 0.5250
# Epoch 12/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.6939 - acc: 0.6250 - val_loss: 0.6913 - val_acc: 0.5500
# Epoch 13/150
# 40/40 [==============================] - 0s 225us/step - loss: 0.6971 - acc: 0.4500 - val_loss: 0.6894 - val_acc: 0.5250
# Epoch 14/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.6850 - acc: 0.5000 - val_loss: 0.6876 - val_acc: 0.5250
# Epoch 15/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.7057 - acc: 0.4500 - val_loss: 0.6857 - val_acc: 0.5500
# Epoch 16/150
# 40/40 [==============================] - 0s 238us/step - loss: 0.7040 - acc: 0.5250 - val_loss: 0.6839 - val_acc: 0.5000
# Epoch 17/150
# 40/40 [==============================] - 0s 225us/step - loss: 0.6874 - acc: 0.5000 - val_loss: 0.6822 - val_acc: 0.5250
# Epoch 18/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.6829 - acc: 0.5250 - val_loss: 0.6805 - val_acc: 0.5250
# Epoch 19/150
# 40/40 [==============================] - 0s 212us/step - loss: 0.6882 - acc: 0.4250 - val_loss: 0.6788 - val_acc: 0.5250
# Epoch 20/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6614 - acc: 0.5750 - val_loss: 0.6772 - val_acc: 0.5500
# Epoch 21/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6827 - acc: 0.5750 - val_loss: 0.6756 - val_acc: 0.5500
# Epoch 22/150
# 40/40 [==============================] - 0s 238us/step - loss: 0.6784 - acc: 0.5500 - val_loss: 0.6738 - val_acc: 0.5500
# Epoch 23/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6891 - acc: 0.4750 - val_loss: 0.6722 - val_acc: 0.5250
# Epoch 24/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.6855 - acc: 0.5250 - val_loss: 0.6706 - val_acc: 0.5250
# Epoch 25/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6708 - acc: 0.5500 - val_loss: 0.6692 - val_acc: 0.5250
# Epoch 26/150
# 40/40 [==============================] - 0s 150us/step - loss: 0.6641 - acc: 0.6000 - val_loss: 0.6675 - val_acc: 0.5500
# Epoch 27/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6719 - acc: 0.4500 - val_loss: 0.6659 - val_acc: 0.5500
# Epoch 28/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.6624 - acc: 0.5750 - val_loss: 0.6643 - val_acc: 0.5500
# Epoch 29/150
# 40/40 [==============================] - 0s 213us/step - loss: 0.6602 - acc: 0.5250 - val_loss: 0.6628 - val_acc: 0.5500
# Epoch 30/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.6705 - acc: 0.5250 - val_loss: 0.6612 - val_acc: 0.5750
# Epoch 31/150
# 40/40 [==============================] - 0s 213us/step - loss: 0.6626 - acc: 0.4750 - val_loss: 0.6596 - val_acc: 0.5750
# Epoch 32/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6605 - acc: 0.5000 - val_loss: 0.6581 - val_acc: 0.5750
# Epoch 33/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6552 - acc: 0.5750 - val_loss: 0.6566 - val_acc: 0.5750
# Epoch 34/150
# 40/40 [==============================] - 0s 212us/step - loss: 0.6561 - acc: 0.5250 - val_loss: 0.6551 - val_acc: 0.5750
# Epoch 35/150
# 40/40 [==============================] - 0s 250us/step - loss: 0.6528 - acc: 0.5250 - val_loss: 0.6536 - val_acc: 0.5750
# Epoch 36/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6512 - acc: 0.6750 - val_loss: 0.6521 - val_acc: 0.5750
# Epoch 37/150
# 40/40 [==============================] - 0s 250us/step - loss: 0.6545 - acc: 0.6750 - val_loss: 0.6506 - val_acc: 0.5750
# Epoch 38/150
# 40/40 [==============================] - 0s 237us/step - loss: 0.6502 - acc: 0.5750 - val_loss: 0.6491 - val_acc: 0.5750
# Epoch 39/150
# 40/40 [==============================] - 0s 250us/step - loss: 0.6651 - acc: 0.5500 - val_loss: 0.6476 - val_acc: 0.5750
# Epoch 40/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6504 - acc: 0.5750 - val_loss: 0.6460 - val_acc: 0.6000
# Epoch 41/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.6454 - acc: 0.6750 - val_loss: 0.6444 - val_acc: 0.6000
# Epoch 42/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6400 - acc: 0.6250 - val_loss: 0.6428 - val_acc: 0.6000
# Epoch 43/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6359 - acc: 0.6500 - val_loss: 0.6413 - val_acc: 0.6000
# Epoch 44/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.6463 - acc: 0.6250 - val_loss: 0.6396 - val_acc: 0.6000
# Epoch 45/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6366 - acc: 0.7000 - val_loss: 0.6380 - val_acc: 0.6000
# Epoch 46/150
# 40/40 [==============================] - 0s 250us/step - loss: 0.6329 - acc: 0.6750 - val_loss: 0.6364 - val_acc: 0.6000
# Epoch 47/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6305 - acc: 0.6000 - val_loss: 0.6348 - val_acc: 0.6500
# Epoch 48/150
# 40/40 [==============================] - 0s 250us/step - loss: 0.6466 - acc: 0.6750 - val_loss: 0.6332 - val_acc: 0.6500
# Epoch 49/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.6400 - acc: 0.6750 - val_loss: 0.6316 - val_acc: 0.6500
# Epoch 50/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.6424 - acc: 0.6750 - val_loss: 0.6300 - val_acc: 0.6500
# Epoch 51/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.6230 - acc: 0.6250 - val_loss: 0.6283 - val_acc: 0.6750
# Epoch 52/150
# 40/40 [==============================] - 0s 225us/step - loss: 0.6301 - acc: 0.6250 - val_loss: 0.6266 - val_acc: 0.6750
# Epoch 53/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.6319 - acc: 0.7000 - val_loss: 0.6249 - val_acc: 0.7000
# Epoch 54/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.6326 - acc: 0.7500 - val_loss: 0.6231 - val_acc: 0.7250
# Epoch 55/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.6293 - acc: 0.7500 - val_loss: 0.6214 - val_acc: 0.7250
# Epoch 56/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.6283 - acc: 0.7000 - val_loss: 0.6197 - val_acc: 0.7250
# Epoch 57/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.6156 - acc: 0.7750 - val_loss: 0.6179 - val_acc: 0.7250
# Epoch 58/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.6215 - acc: 0.7750 - val_loss: 0.6162 - val_acc: 0.7250
# Epoch 59/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.6133 - acc: 0.6500 - val_loss: 0.6144 - val_acc: 0.7250
# Epoch 60/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.6269 - acc: 0.7000 - val_loss: 0.6126 - val_acc: 0.7250
# Epoch 61/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6069 - acc: 0.7750 - val_loss: 0.6109 - val_acc: 0.7250
# Epoch 62/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.6015 - acc: 0.7500 - val_loss: 0.6091 - val_acc: 0.7250
# Epoch 63/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.6208 - acc: 0.6500 - val_loss: 0.6075 - val_acc: 0.7250
# Epoch 64/150
# 40/40 [==============================] - 0s 212us/step - loss: 0.6133 - acc: 0.7000 - val_loss: 0.6057 - val_acc: 0.7250
# Epoch 65/150
# 40/40 [==============================] - 0s 225us/step - loss: 0.6073 - acc: 0.8000 - val_loss: 0.6040 - val_acc: 0.7250
# Epoch 66/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5946 - acc: 0.7500 - val_loss: 0.6022 - val_acc: 0.7250
# Epoch 67/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.6046 - acc: 0.8000 - val_loss: 0.6003 - val_acc: 0.7250
# Epoch 68/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.6006 - acc: 0.7750 - val_loss: 0.5984 - val_acc: 0.7250
# Epoch 69/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.5991 - acc: 0.8250 - val_loss: 0.5966 - val_acc: 0.7500
# Epoch 70/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.5837 - acc: 0.8250 - val_loss: 0.5947 - val_acc: 0.7500
# Epoch 71/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.6055 - acc: 0.7750 - val_loss: 0.5929 - val_acc: 0.7750
# Epoch 72/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5957 - acc: 0.8000 - val_loss: 0.5911 - val_acc: 0.7750
# Epoch 73/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.5894 - acc: 0.8000 - val_loss: 0.5891 - val_acc: 0.7750
# Epoch 74/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5873 - acc: 0.8250 - val_loss: 0.5871 - val_acc: 0.7750
# Epoch 75/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.5825 - acc: 0.7750 - val_loss: 0.5851 - val_acc: 0.8000
# Epoch 76/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.5721 - acc: 0.8750 - val_loss: 0.5832 - val_acc: 0.8000
# Epoch 77/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.5839 - acc: 0.7750 - val_loss: 0.5812 - val_acc: 0.8000
# Epoch 78/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.5732 - acc: 0.8250 - val_loss: 0.5791 - val_acc: 0.8250
# Epoch 79/150
# 40/40 [==============================] - 0s 225us/step - loss: 0.5876 - acc: 0.7750 - val_loss: 0.5771 - val_acc: 0.8500
# Epoch 80/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5746 - acc: 0.8250 - val_loss: 0.5750 - val_acc: 0.8500
# Epoch 81/150
# 40/40 [==============================] - 0s 150us/step - loss: 0.5785 - acc: 0.8750 - val_loss: 0.5728 - val_acc: 0.8500
# Epoch 82/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.5787 - acc: 0.8250 - val_loss: 0.5707 - val_acc: 0.8500
# Epoch 83/150
# 40/40 [==============================] - 0s 263us/step - loss: 0.5802 - acc: 0.8750 - val_loss: 0.5686 - val_acc: 0.8750
# Epoch 84/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.5746 - acc: 0.8250 - val_loss: 0.5665 - val_acc: 0.8750
# Epoch 85/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.5634 - acc: 0.8500 - val_loss: 0.5644 - val_acc: 0.9000
# Epoch 86/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5832 - acc: 0.8250 - val_loss: 0.5623 - val_acc: 0.9000
# Epoch 87/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5696 - acc: 0.8500 - val_loss: 0.5600 - val_acc: 0.9000
# Epoch 88/150
# 40/40 [==============================] - 0s 212us/step - loss: 0.5676 - acc: 0.7750 - val_loss: 0.5578 - val_acc: 0.9000
# Epoch 89/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.5605 - acc: 0.9000 - val_loss: 0.5555 - val_acc: 0.9250
# Epoch 90/150
# 40/40 [==============================] - 0s 150us/step - loss: 0.5647 - acc: 0.8750 - val_loss: 0.5530 - val_acc: 0.9000
# Epoch 91/150
# 40/40 [==============================] - 0s 237us/step - loss: 0.5527 - acc: 0.8250 - val_loss: 0.5507 - val_acc: 0.9250
# Epoch 92/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.5659 - acc: 0.8500 - val_loss: 0.5483 - val_acc: 0.9250
# Epoch 93/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5515 - acc: 0.9000 - val_loss: 0.5458 - val_acc: 0.9500
# Epoch 94/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.5547 - acc: 0.9000 - val_loss: 0.5434 - val_acc: 0.9500
# Epoch 95/150
# 40/40 [==============================] - 0s 213us/step - loss: 0.5577 - acc: 0.8500 - val_loss: 0.5410 - val_acc: 0.9500
# Epoch 96/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5457 - acc: 0.8750 - val_loss: 0.5386 - val_acc: 0.9500
# Epoch 97/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.5382 - acc: 0.9250 - val_loss: 0.5361 - val_acc: 0.9500
# Epoch 98/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.5489 - acc: 0.9000 - val_loss: 0.5338 - val_acc: 0.9500
# Epoch 99/150
# 40/40 [==============================] - 0s 238us/step - loss: 0.5334 - acc: 0.9750 - val_loss: 0.5313 - val_acc: 0.9500
# Epoch 100/150
# 40/40 [==============================] - 0s 150us/step - loss: 0.5155 - acc: 0.9000 - val_loss: 0.5286 - val_acc: 0.9750
# Epoch 101/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.5445 - acc: 0.9000 - val_loss: 0.5261 - val_acc: 0.9750
# Epoch 102/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.5508 - acc: 0.8500 - val_loss: 0.5237 - val_acc: 0.9750
# Epoch 103/150
# 40/40 [==============================] - 0s 225us/step - loss: 0.5320 - acc: 0.8500 - val_loss: 0.5211 - val_acc: 0.9750
# Epoch 104/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.5277 - acc: 0.9250 - val_loss: 0.5182 - val_acc: 0.9750
# Epoch 105/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.5236 - acc: 0.8750 - val_loss: 0.5156 - val_acc: 0.9750
# Epoch 106/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.5077 - acc: 0.9500 - val_loss: 0.5125 - val_acc: 1.0000
# Epoch 107/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.5007 - acc: 0.9750 - val_loss: 0.5096 - val_acc: 1.0000
# Epoch 108/150
# 40/40 [==============================] - 0s 237us/step - loss: 0.5121 - acc: 0.9500 - val_loss: 0.5064 - val_acc: 1.0000
# Epoch 109/150
# 40/40 [==============================] - 0s 250us/step - loss: 0.5235 - acc: 0.9250 - val_loss: 0.5034 - val_acc: 1.0000
# Epoch 110/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.5004 - acc: 0.9250 - val_loss: 0.5002 - val_acc: 1.0000
# Epoch 111/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.5007 - acc: 0.9750 - val_loss: 0.4969 - val_acc: 1.0000
# Epoch 112/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.4876 - acc: 0.9250 - val_loss: 0.4937 - val_acc: 1.0000
# Epoch 113/150
# 40/40 [==============================] - 0s 187us/step - loss: 0.4910 - acc: 0.9500 - val_loss: 0.4905 - val_acc: 1.0000
# Epoch 114/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4920 - acc: 0.9750 - val_loss: 0.4871 - val_acc: 1.0000
# Epoch 115/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4849 - acc: 0.9500 - val_loss: 0.4841 - val_acc: 1.0000
# Epoch 116/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.4812 - acc: 0.9750 - val_loss: 0.4807 - val_acc: 1.0000
# Epoch 117/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4775 - acc: 1.0000 - val_loss: 0.4774 - val_acc: 1.0000
# Epoch 118/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.4905 - acc: 0.9500 - val_loss: 0.4740 - val_acc: 1.0000
# Epoch 119/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4781 - acc: 0.9500 - val_loss: 0.4703 - val_acc: 1.0000
# Epoch 120/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4592 - acc: 1.0000 - val_loss: 0.4667 - val_acc: 1.0000
# Epoch 121/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.4677 - acc: 1.0000 - val_loss: 0.4632 - val_acc: 1.0000
# Epoch 122/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4628 - acc: 1.0000 - val_loss: 0.4598 - val_acc: 1.0000
# Epoch 123/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.4541 - acc: 0.9500 - val_loss: 0.4562 - val_acc: 1.0000
# Epoch 124/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4707 - acc: 0.9750 - val_loss: 0.4524 - val_acc: 1.0000
# Epoch 125/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.4691 - acc: 0.9500 - val_loss: 0.4489 - val_acc: 1.0000
# Epoch 126/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4536 - acc: 1.0000 - val_loss: 0.4454 - val_acc: 1.0000
# Epoch 127/150
# 40/40 [==============================] - 0s 150us/step - loss: 0.4434 - acc: 1.0000 - val_loss: 0.4416 - val_acc: 1.0000
# Epoch 128/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4422 - acc: 1.0000 - val_loss: 0.4385 - val_acc: 1.0000
# Epoch 129/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.4504 - acc: 0.9250 - val_loss: 0.4350 - val_acc: 1.0000
# Epoch 130/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.4368 - acc: 0.9750 - val_loss: 0.4312 - val_acc: 1.0000
# Epoch 131/150
# 40/40 [==============================] - 0s 212us/step - loss: 0.4377 - acc: 0.9750 - val_loss: 0.4272 - val_acc: 1.0000
# Epoch 132/150
# 40/40 [==============================] - 0s 225us/step - loss: 0.4274 - acc: 1.0000 - val_loss: 0.4232 - val_acc: 1.0000
# Epoch 133/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.4234 - acc: 1.0000 - val_loss: 0.4197 - val_acc: 1.0000
# Epoch 134/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.4165 - acc: 1.0000 - val_loss: 0.4159 - val_acc: 1.0000
# Epoch 135/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.4128 - acc: 1.0000 - val_loss: 0.4121 - val_acc: 1.0000
# Epoch 136/150
# 40/40 [==============================] - 0s 212us/step - loss: 0.4137 - acc: 0.9750 - val_loss: 0.4081 - val_acc: 1.0000
# Epoch 137/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4017 - acc: 1.0000 - val_loss: 0.4039 - val_acc: 1.0000
# Epoch 138/150
# 40/40 [==============================] - 0s 212us/step - loss: 0.4081 - acc: 0.9750 - val_loss: 0.4000 - val_acc: 1.0000
# Epoch 139/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.3912 - acc: 0.9750 - val_loss: 0.3961 - val_acc: 1.0000
# Epoch 140/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.3914 - acc: 0.9250 - val_loss: 0.3922 - val_acc: 1.0000
# Epoch 141/150
# 40/40 [==============================] - 0s 212us/step - loss: 0.3895 - acc: 1.0000 - val_loss: 0.3883 - val_acc: 1.0000
# Epoch 142/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.4004 - acc: 1.0000 - val_loss: 0.3846 - val_acc: 1.0000
# Epoch 143/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.3896 - acc: 0.9750 - val_loss: 0.3805 - val_acc: 1.0000
# Epoch 144/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.3875 - acc: 0.9750 - val_loss: 0.3766 - val_acc: 1.0000
# Epoch 145/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.3785 - acc: 0.9250 - val_loss: 0.3727 - val_acc: 1.0000
# Epoch 146/150
# 40/40 [==============================] - 0s 175us/step - loss: 0.3858 - acc: 0.9750 - val_loss: 0.3691 - val_acc: 1.0000
# Epoch 147/150
# 40/40 [==============================] - 0s 163us/step - loss: 0.3720 - acc: 0.9500 - val_loss: 0.3650 - val_acc: 1.0000
# Epoch 148/150
# 40/40 [==============================] - 0s 200us/step - loss: 0.3911 - acc: 0.9500 - val_loss: 0.3616 - val_acc: 1.0000
# Epoch 149/150
# 40/40 [==============================] - 0s 162us/step - loss: 0.3539 - acc: 1.0000 - val_loss: 0.3575 - val_acc: 1.0000
# Epoch 150/150
# 40/40 [==============================] - 0s 188us/step - loss: 0.3653 - acc: 0.9500 - val_loss: 0.3536 - val_acc: 1.0000

# %%
print('evaluating new model')
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# evaluating new model
# Test score: 0.353582644463
# Test accuracy: 1.0

# %%
def plot_history(history, metric='acc', loc='lower right'): 
    # list all data in history
    # print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric])
    if metric == 'acc': 
        metric = 'accuracy'
    plt.title('model ' + metric)
    plt.ylabel(metric)
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc=loc)
    plt.show()

# %%
plot_history(history)

# %%
def predictions(data, probability=True):
    pred = np.array(model.predict_classes(data), dtype=np.int32)
    confidence = []
    if probability:
        confidence = model.predict(data)
    pred_class = [class_names[n] for n in pred]
    return pred_class, confidence

# %%
(blind_data, blind_data_ids) = load_blind_data(coefficients, force=True)
pred_class, confidence = predictions(blind_data)

# %%
def output_prediction_csv(blind_data_ids, pred_class, confidence):
    string = "id; predicted class; confidence\n"
    for index, val in enumerate(pred_class):
        string += blind_data_ids[index] + ";" + pred_class[index] + ";" + str(max(confidence[index])*100) + "%\n"
    return string

# %%
print(output_prediction_csv(blind_data_ids, pred_class, confidence))
# Out:
# id; predicted class; confidence
# P41;NORMAL;65.7623231411%
# P42;NORMAL;59.0517222881%
# P43;NORMAL;73.5103130341%
# P44;NORMAL;68.3148980141%
# P45;NORMAL;65.2839303017%
# P46;NORMAL;69.2266464233%
# P47;NORMAL;71.4043140411%
# P48;NORMAL;70.7800269127%
# P49;NORMAL;77.3246943951%
# P50;NORMAL;70.1256453991%
# P51;NORMAL;74.5649337769%
# P52;NORMAL;73.2305467129%
# P53;NORMAL;63.942617178%
# P54;NORMAL;68.7407195568%
# P55;NORMAL;63.559371233%
# P56;NORMAL;60.1560115814%
# P57;NORMAL;63.1248891354%
# P58;NORMAL;73.0675816536%
# P59;NORMAL;63.0572259426%
# P60;NORMAL;73.0524122715%
# P61;NORMAL;61.8290066719%
# P62;NORMAL;69.9579119682%
# P63;NORMAL;70.202678442%
# P64;NORMAL;66.0168588161%
# P65;NORMAL;51.8779635429%
# P66;NORMAL;65.4132246971%
# P67;TRISOMY 21;80.0403058529%
# P68;TRISOMY 21;60.4067027569%
# P69;TRISOMY 21;99.9999880791%
# P70;TRISOMY 21;99.8254597187%
# P71;TRISOMY 21;81.2159359455%
# P72;TRISOMY 21;89.3629848957%
# P73;TRISOMY 21;89.4285559654%
# P74;TRISOMY 21;89.0476167202%
# P75;TRISOMY 21;99.9242424965%
# P76;TRISOMY 21;91.7467713356%
# P77;TRISOMY 21;99.9950170517%
# P78;TRISOMY 21;99.879348278%
# P79;TRISOMY 21;99.7501552105%
# P80;TRISOMY 21;100.0%
